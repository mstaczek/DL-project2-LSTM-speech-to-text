# %% [markdown]
# # Whisper predictions analysis - Large model

# %%
from whisper_automatic_analysis import WhisperAutoAnalysis

# MODEL_SIZE_NAME = 'medium'
MODEL_SIZE_NAME = 'large'

FILTER = 'test classes'
# FILTER = 'number classes'
# FILTER = 'other'
# FILTER = 'all'

waa = WhisperAutoAnalysis()
waa.analyze(MODEL_SIZE_NAME, FILTER)

# %%
from whisper_automatic_analysis import WhisperAutoAnalysis

# MODEL_SIZE_NAME = 'medium'
MODEL_SIZE_NAME = 'large'

# FILTER = 'test classes'
FILTER = 'number classes'
# FILTER = 'other'
# FILTER = 'all'

waa = WhisperAutoAnalysis()
waa.analyze(MODEL_SIZE_NAME, FILTER)

# %%
from whisper_automatic_analysis import WhisperAutoAnalysis

# MODEL_SIZE_NAME = 'medium'
MODEL_SIZE_NAME = 'large'

# FILTER = 'test classes'
# FILTER = 'number classes'
FILTER = 'other'
# FILTER = 'all'

waa = WhisperAutoAnalysis()
waa.analyze(MODEL_SIZE_NAME, FILTER)

# %%
from whisper_automatic_analysis import WhisperAutoAnalysis

# MODEL_SIZE_NAME = 'medium'
MODEL_SIZE_NAME = 'large'

# FILTER = 'test classes'
# FILTER = 'number classes'
# FILTER = 'other'
FILTER = 'all'

waa = WhisperAutoAnalysis()
waa.analyze(MODEL_SIZE_NAME, FILTER)

# %% [markdown]
# # Medium model

# %%
from whisper_automatic_analysis import WhisperAutoAnalysis

MODEL_SIZE_NAME = 'medium'
# MODEL_SIZE_NAME = 'large'

FILTER = 'test classes'
# FILTER = 'number classes'
# FILTER = 'other'
# FILTER = 'all'

waa = WhisperAutoAnalysis()
waa.analyze(MODEL_SIZE_NAME, FILTER)

# %%
from whisper_automatic_analysis import WhisperAutoAnalysis

MODEL_SIZE_NAME = 'medium'
# MODEL_SIZE_NAME = 'large'

# FILTER = 'test classes'
FILTER = 'number classes'
# FILTER = 'other'
# FILTER = 'all'

waa = WhisperAutoAnalysis()
waa.analyze(MODEL_SIZE_NAME, FILTER)

# %%
from whisper_automatic_analysis import WhisperAutoAnalysis

MODEL_SIZE_NAME = 'medium'
# MODEL_SIZE_NAME = 'large'

# FILTER = 'test classes'
# FILTER = 'number classes'
FILTER = 'other'
# FILTER = 'all'

waa = WhisperAutoAnalysis()
waa.analyze(MODEL_SIZE_NAME, FILTER)

# %%
from whisper_automatic_analysis import WhisperAutoAnalysis

MODEL_SIZE_NAME = 'medium'
# MODEL_SIZE_NAME = 'large'

# FILTER = 'test classes'
# FILTER = 'number classes'
# FILTER = 'other'
FILTER = 'all'

waa = WhisperAutoAnalysis()
waa.analyze(MODEL_SIZE_NAME, FILTER)
